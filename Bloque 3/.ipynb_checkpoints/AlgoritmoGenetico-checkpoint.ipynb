# %% [markdown]
# Comenzamos por importar las librerías correspondientes

# %%
import random
import string
from fuzzywuzzy import fuzz

# %% [markdown]
# Luego definimos las variables que utilizaremos como parámetros generales del algoritmo

# %%
in_str = None
in_str_len = None
population = #SuCódigoAquí
generations = #SuCódigoAquí

# %%
class Agent:

    def __init__(self, length):
        self.string = "".join(random.choice(string.ascii_letters) for _ in range(length))
        self.fitness = -1

    def __str__(self):
        return "String: " + str(self.string) + " aptitud: " + str(self.fitness)

# %%
def ga():
    agents = init_agents(population,in_str_len)

    threshold = False    
    for generation in range(generations):
            

        agents = fitness(agents)
        agents = selection(agents)
        agents = crossover(agents)
        agents = mutation(agents)

        for agent in agents:
            if agent.fitness == 100:
                print ("Generación " + str(generation) + ". Convergió: " + str(agent))
                threshold = True
        if threshold:
            break
        else:
            print ("Generación " + str(generation) + ": " + str(agents[0]))

# %%
def init_agents(population,length):
    return #SuCódigoAquí

def fitness(agents):
    for agent in agents:
        agent.fitness = fuzz.ratio(agent.string, in_str)
    return agents

def selection(agents):
    agents = sorted(agents, key=lambda agent: agent.fitness, reverse=True)
    agents = agents[:int(0.2 * len(agents))]
    return agents

def crossover(agents):
    offspring = []
    for _ in  range(int((population - len(agents)) / 2)):
        parent1 = random.choice(agents)
        parent2 = random.choice(agents)
        child1 =  Agent(in_str_len)
        child2 =  Agent(in_str_len)
        split = random.randint(0, in_str_len)
        child1.string = parent1.string[0:split] + parent2.string[split:in_str_len]
        child2.string = parent2.string[0:split] + parent1.string[split:in_str_len]

        offspring.append(child1)
        offspring.append(child2)

    agents.extend(offspring)

    return agents

def mutation(agents):
    for agent in agents:
        for idx, param in enumerate(agent.string):
            if random.uniform(0.0, 1.0) <= 0.1:
                agent.string = agent.string[0:idx] + random.choice(string.ascii_letters) + agent.string[idx+1:in_str_len]
    return agents

# %%
in_str = "casa"
in_str_len = len(in_str)
ga()
# Out:
# Generación 0: String: EsBP aptitud: 25
# Generación 1: String: slga aptitud: 50
# Generación 2: String: Klga aptitud: 50
# Generación 3: String: abMa aptitud: 50
# Generación 4: String: abMa aptitud: 50
# Generación 5: String: ObMv aptitud: 50
# Generación 6: String: abpN aptitud: 50
# Generación 7: String: aDsa aptitud: 75
# Generación 8: String: aDsa aptitud: 75
# Generación 9: String: aDsa aptitud: 75
# Generación 10: String: aDsa aptitud: 75
# Generación 11: String: aDsa aptitud: 75
# Generación 12: String: bXAa aptitud: 75
# Generación 13: String: adsa aptitud: 75
# Generación 14: String: adKa aptitud: 75
# Generación 15: String: aDWa aptitud: 75
# Generación 16: String: zXsa aptitud: 75
# Generación 17: String: agsa aptitud: 75
# Generación 18: String: agsa aptitud: 75
# Generación 19: String: Vgsa aptitud: 75
# Generación 20: String: aDsa aptitud: 75
# Generación 21: String: aDsa aptitud: 75
# Generación 22: String: aDsa aptitud: 75
# Generación 23: String: aDsa aptitud: 75
# Generación 24: String: aDYa aptitud: 75
# Generación 25: String: assa aptitud: 75
# Generación 26: String: assa aptitud: 75
# Generación 27: String: assa aptitud: 75
# Generación 28: String: Bssa aptitud: 75
# Generación 29: String: aDHa aptitud: 75
# Generación 30: String: aTAa aptitud: 75
# Generación 31: String: assa aptitud: 75
# Generación 32: String: assa aptitud: 75
# Generación 33: String: amsa aptitud: 75
# Generación 34: String: amsa aptitud: 75
# Generación 35: String: amsa aptitud: 75
# Generación 36: String: amsa aptitud: 75
# Generación 37: String: amsa aptitud: 75
# Generación 38: String: amsa aptitud: 75
# Generación 39: String: amsK aptitud: 75
# Generación 40: String: aJsa aptitud: 75
# Generación 41: String: aJsa aptitud: 75
# Generación 42: String: aJWa aptitud: 75
# Generación 43: String: avsa aptitud: 75
# Generación 44: String: alsa aptitud: 75
# Generación 45: String: alza aptitud: 75
# Generación 46: String: assa aptitud: 75
# Generación 47: String: assa aptitud: 75
# Generación 48: String: assa aptitud: 75
# Generación 49: String: assa aptitud: 75
# Generación 50: String: assa aptitud: 75
# Generación 51: String: assa aptitud: 75
# Generación 52: String: assa aptitud: 75
# Generación 53: String: assa aptitud: 75
# Generación 54: String: assa aptitud: 75
# Generación 55: String: assR aptitud: 75
# Generación 56: String: assa aptitud: 75
# Generación 57: String: assa aptitud: 75
# Generación 58: String: assa aptitud: 75
# Generación 59: String: assa aptitud: 75
# Generación 60: String: assF aptitud: 75
# Generación 61: String: assa aptitud: 75
# Generación 62: String: assa aptitud: 75
# Generación 63: String: assa aptitud: 75
# Generación 64: String: assa aptitud: 75
# Generación 65: String: assa aptitud: 75
# Generación 66: String: assa aptitud: 75
# Generación 67: String: assa aptitud: 75
# Generación 68: String: assa aptitud: 75
# Generación 69: String: adsa aptitud: 75
# Generación 70: String: adsa aptitud: 75
# Generación 71: String: adsa aptitud: 75
# Generación 72: String: adda aptitud: 75
# Generación 73: String: asGa aptitud: 75
# Generación 74: String: asGa aptitud: 75
# Generación 75: String: asGa aptitud: 75
# Generación 76: String: asGa aptitud: 75
# Generación 77: String: asGa aptitud: 75
# Generación 78: String: asGa aptitud: 75
# Generación 79: String: asGa aptitud: 75
# Generación 80: String: asGa aptitud: 75
# Generación 81: String: YsGa aptitud: 75
# Generación 82: String: asGa aptitud: 75
# Generación 83: String: asGa aptitud: 75
# Generación 84: String: auGa aptitud: 75
# Generación 85: String: adsa aptitud: 75
# Generación 86: String: adAa aptitud: 75
# Generación 87: String: asTa aptitud: 75
# Generación 88: String: asTa aptitud: 75
# Generación 89: String: asTa aptitud: 75
# Generación 90: String: amTa aptitud: 75
# Generación 91: String: aswa aptitud: 75
# Generación 92: String: aswa aptitud: 75
# Generación 93: String: aswa aptitud: 75
# Generación 94: String: aswa aptitud: 75
# Generación 95: String: aDwa aptitud: 75
# Generación 96: String: asOa aptitud: 75
# Generación 97: String: asOa aptitud: 75
# Generación 98: String: asOa aptitud: 75
# Generación 99: String: asOP aptitud: 75
# Generación 100: String: aIoa aptitud: 75
# Generación 101: String: aswa aptitud: 75
# Generación 102: String: aswa aptitud: 75
# Generación 103: String: aswa aptitud: 75
# Generación 104: String: aswa aptitud: 75
# Generación 105: String: aswS aptitud: 75
# Generación 106: String: avZa aptitud: 75
# Generación 107: String: asXa aptitud: 75
# Generación 108: String: asXa aptitud: 75
# Generación 109: String: aEja aptitud: 75
# Generación 110: String: asZa aptitud: 75
# Generación 111: String: EUZa aptitud: 75
# Generación 112: String: asZa aptitud: 75
# Generación 113: String: asZa aptitud: 75
# Generación 114: String: asZa aptitud: 75
# Generación 115: String: asZa aptitud: 75
# Generación 116: String: asZa aptitud: 75
# Generación 117: String: asZa aptitud: 75
# Generación 118: String: asZa aptitud: 75
# Generación 119: String: asZa aptitud: 75
# Generación 120: String: asZa aptitud: 75
# Generación 121: String: asZa aptitud: 75
# Generación 122: String: csZa aptitud: 75
# Generación 123: String: csZa aptitud: 75
# Generación 124: String: csZa aptitud: 75
# Generación 125: String: csZa aptitud: 75
# Generación 126: String: psZD aptitud: 75
# Generación 127: String: asRa aptitud: 75
# Generación 128: String: asRa aptitud: 75
# Generación 129: String: asGa aptitud: 75
# Generación 130: String: asGQ aptitud: 75
# Generación 131: String: aspa aptitud: 75
# Generación 132: String: Lspa aptitud: 75
# Generación 133: String: XsRa aptitud: 75
# Generación 134: String: aqpa aptitud: 75
# Generación 135: String: aspa aptitud: 75
# Generación 136: String: aspL aptitud: 75
# Generación 137: String: aspa aptitud: 75
# Generación 138: String: aspa aptitud: 75
# Generación 139: String: aspa aptitud: 75
# Generación 140: String: aspa aptitud: 75
# Generación 141: String: abpa aptitud: 75
# Generación 142: String: aspa aptitud: 75
# Generación 143: String: aspa aptitud: 75
# Generación 144: String: aSpa aptitud: 75
# Generación 145: String: asaa aptitud: 75
# Generación 146: String: asaa aptitud: 75
# Generación 147: String: asaa aptitud: 75
# Generación 148: String: asaa aptitud: 75
# Generación 149: String: asaa aptitud: 75
# Generación 150: String: asaa aptitud: 75
# Generación 151: String: aJaa aptitud: 75
# Generación 152: String: asxa aptitud: 75
# Generación 153: String: asxa aptitud: 75
# Generación 154: String: asxa aptitud: 75
# Generación 155: String: asxa aptitud: 75
# Generación 156: String: asxa aptitud: 75
# Generación 157: String: asxa aptitud: 75
# Generación 158: String: aRxa aptitud: 75
# Generación 159: String: Rsya aptitud: 75
# Generación 160: String: asna aptitud: 75
# Generación 161: String: asna aptitud: 75
# Generación 162: String: asna aptitud: 75
# Generación 163: String: asna aptitud: 75
# Generación 164: String: asna aptitud: 75
# Generación 165: String: asna aptitud: 75
# Generación 166: String: asna aptitud: 75
# Generación 167: String: asna aptitud: 75
# Generación 168: String: asnx aptitud: 75
# Generación 169: String: aXca aptitud: 75
# Generación 170: String: aAZa aptitud: 75
# Generación 171: String: asRa aptitud: 75
# Generación 172: String: asRa aptitud: 75
# Generación 173: String: asRa aptitud: 75
# Generación 174: String: aiRa aptitud: 75
# Generación 175: String: aswa aptitud: 75
# Generación 176: String: duwa aptitud: 75
# Generación 177: String: asiE aptitud: 75
# Generación 178: String: asta aptitud: 75
# Generación 179: String: asta aptitud: 75
# Generación 180: String: asta aptitud: 75
# Generación 181: String: aZta aptitud: 75
# Generación 182: String: asRa aptitud: 75
# Generación 183: String: asDa aptitud: 75
# Generación 184: String: asDa aptitud: 75
# Generación 185: String: asDq aptitud: 75
# Generación 186: String: asMa aptitud: 75
# Generación 187: String: asMa aptitud: 75
# Generación 188: String: asMa aptitud: 75
# Generación 189: String: asMa aptitud: 75
# Generación 190: String: Dsha aptitud: 75
# Generación 191: String: assa aptitud: 75
# Generación 192: String: assa aptitud: 75
# Generación 193: String: assP aptitud: 75
# Generación 194: String: csga aptitud: 75
# Generación 195: String: csga aptitud: 75
# Generación 196: String: csga aptitud: 75
# Generación 197: String: csga aptitud: 75
# Generación 198: String: Esga aptitud: 75
# Generación 199: String: aska aptitud: 75
# Generación 200: String: aska aptitud: 75
# Generación 201: String: aska aptitud: 75
# Generación 202: String: iska aptitud: 75
# Generación 203: String: asXa aptitud: 75
# Generación 204: String: asXa aptitud: 75
# Generación 205: String: asXa aptitud: 75
# Generación 206: String: aCXa aptitud: 75
# Generación 207: String: cdsa aptitud: 75
# Generación 208: String: cdsa aptitud: 75
# Generación 209: String: cdsa aptitud: 75
# Generación 210: String: cdsa aptitud: 75
# Generación 211: String: cdsa aptitud: 75
# Generación 212: String: clsa aptitud: 75
# Generación 213: String: clsa aptitud: 75
# Generación 214: String: clsO aptitud: 75
# Generación 215: String: asna aptitud: 75
# Generación 216: String: asna aptitud: 75
# Generación 217: String: asna aptitud: 75
# Generación 218: String: asna aptitud: 75
# Generación 219: String: asnu aptitud: 75
# Generación 220: String: Usta aptitud: 75
# Generación 221: String: asta aptitud: 75
# Generación 222: String: asta aptitud: 75
# Generación 223: String: amta aptitud: 75
# Generación 224: String: asss aptitud: 75
# Generación 225: String: asva aptitud: 75
# Generación 226: String: asva aptitud: 75
# Generación 227: String: asva aptitud: 75
# Generación 228: String: asvW aptitud: 75
# Generación 229: String: aDsa aptitud: 75
# Generación 230: String: aDsa aptitud: 75
# Generación 231: String: aDsa aptitud: 75
# Generación 232: String: aDsa aptitud: 75
# Generación 233: String: aDsa aptitud: 75
# Generación 234: String: aDsa aptitud: 75
# Generación 235: String: aDma aptitud: 75
# Generación 236: String: Rasa aptitud: 75
# Generación 237: String: Rasa aptitud: 75
# Generación 238: String: Rasa aptitud: 75
# Generación 239: String: Rase aptitud: 75
# Generación 240: String: aSsa aptitud: 75
# Generación 241: String: aSsa aptitud: 75
# Generación 242: String: aSsa aptitud: 75
# Generación 243: String: aSZa aptitud: 75
# Generación 244: String: aSsa aptitud: 75
# Generación 245: String: aSsa aptitud: 75
# Generación 246: String: aSsa aptitud: 75
# Generación 247: String: agsa aptitud: 75
# Generación 248: String: Agsa aptitud: 75
# Generación 249: String: aSsa aptitud: 75
# Generación 250: String: aSsa aptitud: 75
# Generación 251: String: aSsa aptitud: 75
# Generación 252: String: aSsa aptitud: 75
# Generación 253: String: aSsa aptitud: 75
# Generación 254: String: aSsG aptitud: 75
# Generación 255: String: aXsa aptitud: 75
# Generación 256: String: aXsa aptitud: 75
# Generación 257: String: aKsa aptitud: 75
# Generación 258: String: aKsa aptitud: 75
# Generación 259: String: aKsa aptitud: 75
# Generación 260: String: aKsp aptitud: 75
# Generación 261: String: aSsS aptitud: 75
# Generación 262: String: avso aptitud: 75
# Generación 263: String: aOsa aptitud: 75
# Generación 264: String: aOsa aptitud: 75
# Generación 265: String: aOsa aptitud: 75
# Generación 266: String: aOsa aptitud: 75
# Generación 267: String: aOsa aptitud: 75
# Generación 268: String: nOsa aptitud: 75
# Generación 269: String: aKsa aptitud: 75
# Generación 270: String: aKsn aptitud: 75
# Generación 271: String: aKsk aptitud: 75
# Generación 272: String: aKJa aptitud: 75
# Generación 273: String: aKua aptitud: 75
# Generación 274: String: aKsa aptitud: 75
# Generación 275: String: aMsa aptitud: 75
# Generación 276: String: CMsa aptitud: 75
# Generación 277: String: aKsa aptitud: 75
# Generación 278: String: aKsa aptitud: 75
# Generación 279: String: aKya aptitud: 75
# Generación 280: String: aKsa aptitud: 75
# Generación 281: String: aKsa aptitud: 75
# Generación 282: String: aKsa aptitud: 75
# Generación 283: String: aKsa aptitud: 75
# Generación 284: String: aKsa aptitud: 75
# Generación 285: String: aKsa aptitud: 75
# Generación 286: String: aKsa aptitud: 75
# Generación 287: String: aKsa aptitud: 75
# Generación 288: String: aKsa aptitud: 75
# Generación 289: String: aKsa aptitud: 75
# Generación 290: String: aKsa aptitud: 75
# Generación 291: String: aKsa aptitud: 75
# Generación 292: String: aKsa aptitud: 75
# Generación 293: String: aKsa aptitud: 75
# Generación 294: String: aKsa aptitud: 75
# Generación 295: String: aKsa aptitud: 75
# Generación 296: String: aKta aptitud: 75
# Generación 297: String: gaNa aptitud: 75
# Generación 298. Convergió: String: casa aptitud: 100
